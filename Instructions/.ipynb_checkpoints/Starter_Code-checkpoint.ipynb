# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# %%
# Determine the number of unique values in each column.
n = application_df.nunique(axis=0)
n
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# histogram
# hist = application_df.hist(column='APPLICATION_TYPE')
application_df['APPLICATION_TYPE'].value_counts().plot(kind='bar')

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(['T13', 'T12', 'T2','T25','T14','T29','T15','T17'], 'Other')

# %%
application_df['APPLICATION_TYPE']
# Out:
# 0        T10
# 1         T3
# 2         T5
# 3         T3
# 4         T3
#         ...
# 34294     T4
# 34295     T4
# 34296     T3
# 34297     T5
# 34298     T3
# Name: APPLICATION_TYPE, Length: 34299, dtype: object

# %%
# histogram
application_df['APPLICATION_TYPE'].value_counts().plot(kind='bar')

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

# # Replace in dataframe
# for app in application_types_to_replace:
#     application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# # Check to make sure binning was successful
# application_df['APPLICATION_TYPE'].value_counts()

# %%
# Look at CLASSIFICATION value counts for binning
# histogram
application_df['CLASSIFICATION'].value_counts().plot(kind='bar')

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_n = application_df['CLASSIFICATION'].value_counts()
#select n greater than 1
classification_n[classification_n > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1600        5
# C1257        5
# C0           3
# C1260        3
# C2710        3
# C1246        2
# C1267        2
# C1256        2
# C3200        2
# C1234        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = classification_n[classification_n <= 20]
classifications_to_replace.index


# # Replace in dataframe
# for cls in classifications_to_replace:
#     application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# # Check to make sure binning was successful
# application_df['CLASSIFICATION'].value_counts()
# Out:
# Index(['C8000', 'C7120', 'C1500', 'C6000', 'C1800', 'C1250', 'C8200', 'C1238',
#        'C1278', 'C1237', 'C1235', 'C7210', 'C1720', 'C4100', 'C2400', 'C1600',
#        'C1257', 'C0', 'C1260', 'C2710', 'C1246', 'C1267', 'C1256', 'C3200',
#        'C1234', 'C1728', 'C2380', 'C2600', 'C1245', 'C1570', 'C1580', 'C2570',
#        'C4120', 'C5200', 'C2190', 'C2561', 'C1732', 'C1900', 'C1236', 'C2500',
#        'C3700', 'C4200', 'C2150', 'C1820', 'C6100', 'C8210', 'C1248', 'C4500',
#        'C2170', 'C1370', 'C1283'],
#       dtype='object')

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(classifications_to_replace.index, 'Other')

# %%
# # Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# Other      227
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# Name: CLASSIFICATION, dtype: int64

# %%
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 60 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE

target_y = application_df["IS_SUCCESSFUL"]

features_x = application_df.drop(columns=["IS_SUCCESSFUL"])

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE

x_train, x_test, y_train, y_test = train_test_split(features_x, target_y)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((25724, 59), (8575, 59), (25724,), (8575,))

# %%
# Create a StandardScaler instances  (make it into normal distribution)
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE  (nn is neural network)

nn = tf.keras.models.Sequential()

n_input_features = 59
n_hidden_neurons = 8

# set up the first input / features layer
nn.add(tf.keras.Input(shape=(n_input_features,)))


# First hidden layer
#  YOUR CODE GOES HERE

nn.add(tf.keras.layers.Dense(n_hidden_neurons, activation="relu"))


#  YOUR CODE GOES HERE

nn.add(tf.keras.layers.Dense(n_hidden_neurons, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
# Doing binary classification, so need 1 as output
nn.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 480
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 561
# Trainable params: 561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
# This builds the model for the first time:

nn.compile(loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE

nn.fit(x_train_scaled, y_train, batch_size=64, epochs=30)
# Out:
# Epoch 1/30
# 402/402 [==============================] - 1s 2ms/step - loss: 0.6310 - accuracy: 0.6748
# Epoch 2/30
# 402/402 [==============================] - 1s 2ms/step - loss: 0.5745 - accuracy: 0.7190: 0s - loss: 0.5763 - ac
# Epoch 3/30
# 402/402 [==============================] - 1s 2ms/step - loss: 0.5661 - accuracy: 0.7202
# Epoch 4/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5627 - accuracy: 0.7213
# Epoch 5/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5606 - accuracy: 0.7240
# Epoch 6/30
# 402/402 [==============================] - 1s 2ms/step - loss: 0.5592 - accuracy: 0.7238
# Epoch 7/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5580 - accuracy: 0.7247
# Epoch 8/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5567 - accuracy: 0.7263
# Epoch 9/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7268
# Epoch 10/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5556 - accuracy: 0.7270
# Epoch 11/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5553 - accuracy: 0.7272
# Epoch 12/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5545 - accuracy: 0.7275
# Epoch 13/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5543 - accuracy: 0.7292
# Epoch 14/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5540 - accuracy: 0.7285
# Epoch 15/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.7287
# Epoch 16/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5532 - accuracy: 0.7286
# Epoch 17/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5526 - accuracy: 0.7296
# Epoch 18/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5522 - accuracy: 0.7295
# Epoch 19/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5521 - accuracy: 0.7301
# Epoch 20/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5517 - accuracy: 0.7295
# Epoch 21/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5514 - accuracy: 0.7298
# Epoch 22/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5513 - accuracy: 0.7298
# Epoch 23/30
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5511 - accuracy: 0.7308
# Epoch 24/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7302
# Epoch 25/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5508 - accuracy: 0.7312
# Epoch 26/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7303
# Epoch 27/30
# 402/402 [==============================] - 1s 2ms/step - loss: 0.5503 - accuracy: 0.7306
# Epoch 28/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7313
# Epoch 29/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7307
# Epoch 30/30
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7308

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 268/268 - 0s - loss: 0.5477 - accuracy: 0.7366
# Loss: 0.547705352306366, Accuracy: 0.7365597486495972

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
